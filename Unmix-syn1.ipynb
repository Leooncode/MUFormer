# %%
from utils.VCA import *
import numpy as np
import torch.nn as nn
import torch
import os
import random
import scipy.io as io
import torch.nn.functional as F

L = 224
P = 3
nr1 = 50
nc1 = 50
T = 6

End_path = './data/endmembers_vca_synth_ex1.mat'
M0 = io.loadmat(End_path)
M0 = torch.tensor(M0['M0']).float().to('cuda:0')


def seed_everything(seed=999):
    '''
     set seed
    :param seed:
    :param device:
    :return:
    '''
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    # some cudnn methods can be random even after fixing the seed unless you tell it to be deterministic
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
seed_everything()

def endmember(HSI):
    E_torch, _ = vca(HSI, P, snr_input=30)
    return E_torch

def deal_end(end):
    end = end.unsqueeze(2).unsqueeze(3).float()
    return end

def np_to_torch(img_np):
    '''Converts image in numpy.array to torch.Tensor.

    From C x W x H [0..1] to  C x W x H [0..1]
    '''
    img_np.astype(np.float32)
    return torch.from_numpy(img_np)

def End_deal(path, device):
    HSI = io.loadmat(path)
    HSI = HSI['Y'].transpose([3, 0, 1, 2])
    HSI = torch.tensor(HSI)
    HSI_1 = HSI[0, :, :, :].reshape(L, -1)
    HSI_2 = HSI[1, :, :, :].reshape(L, -1)
    HSI_3 = HSI[2, :, :, :].reshape(L, -1)
    HSI_4 = HSI[3, :, :, :].reshape(L, -1)
    HSI_5 = HSI[4, :, :, :].reshape(L, -1)
    HSI_6 = HSI[5, :, :, :].reshape(L, -1)
    
    Endmember_1 = endmember(HSI_1)
    Endmember_2 = endmember(HSI_2)
    Endmember_3 = endmember(HSI_3)
    Endmember_4 = endmember(HSI_4)
    Endmember_5 = endmember(HSI_5)
    Endmember_6 = endmember(HSI_6)
    
    Endmember_1 = np_to_torch(Endmember_1)
    Endmember_2 = np_to_torch(Endmember_2)
    Endmember_3 = np_to_torch(Endmember_3)
    Endmember_4 = np_to_torch(Endmember_4)
    Endmember_5 = np_to_torch(Endmember_5)
    Endmember_6 = np_to_torch(Endmember_6)
    
    Endmember_1 = Endmember_1.to(device)
    Endmember_2 = Endmember_2.to(device)
    Endmember_3 = Endmember_3.to(device)
    Endmember_4 = Endmember_4.to(device)
    Endmember_5 = Endmember_5.to(device)
    Endmember_6 = Endmember_6.to(device)

    # Endmember_1 = deal_end(Endmember_1)
    # Endmember_2 = deal_end(Endmember_2)
    # Endmember_3 = deal_end(Endmember_3)
    # Endmember_4 = deal_end(Endmember_4)
    # Endmember_5 = deal_end(Endmember_5)
    # Endmember_6 = deal_end(Endmember_6)

    Endmember_1[Endmember_1 < 0] = 0
    Endmember_2[Endmember_2 < 0] = 0
    Endmember_3[Endmember_3 < 0] = 0
    Endmember_4[Endmember_4 < 0] = 0
    Endmember_5[Endmember_5 < 0] = 0
    Endmember_6[Endmember_6 < 0] = 0

    HSI = HSI.contiguous().view(1, T, L, 50, 50).float()
    HSI = HSI.to(device)
    return Endmember_1, Endmember_2, Endmember_3, Endmember_4, Endmember_5, Endmember_6, HSI


class NonZeroClipper(object):
    def __call__(self, module):
        if hasattr(module, 'weight'):
            w = module.weight.data
            w.clamp_(1e-6, 1)

def Nuclear_norm(inputs):
    band, h, w = inputs.shape
    input = torch.reshape(inputs, (band, h*w))
    out = torch.norm(input, p='nuc')
    return out


def end_loss(HSI, End):
    End = End.cpu()
    O = torch.mean(HSI.view(L,nr1*nc1),1).view(L,1).cpu() # (224, 1)
    B = torch.from_numpy(np.identity(P)).float()  #(3, 3)
    loss_end = torch.norm(torch.mm(End, B.view((P, P))) - O, 'fro')**2
    
    return loss_end.cuda()

class SparseKLloss(nn.Module):
    def __init__(self):
        super(SparseKLloss, self).__init__()

    def __call__(self, input, decay=4e-4):
        input = torch.sum(input, 0, keepdim=True)
        loss = Nuclear_norm(input)
        return decay * loss
        
class SAD(nn.Module):
    def __init__(self, num_bands):
        super(SAD, self).__init__()
        self.num_bands = num_bands

    def forward(self, inp, target):
        input_norm = torch.sqrt(torch.bmm(inp.view(-1, 1, self.num_bands),
                                          inp.view(-1, self.num_bands, 1)))
        target_norm = torch.sqrt(torch.bmm(target.view(-1, 1, self.num_bands),
                                           target.view(-1, self.num_bands, 1)))

        summation = torch.bmm(inp.view(-1, 1, self.num_bands), target.view(-1, self.num_bands, 1))
        angle = torch.acos(summation / (input_norm * target_norm))

        return angle

loss2 = SAD(L)

def sad_loss(out, HSI):
    # print(out.shape)
    # print(HSI.shape)  
    loss_sad_1 = loss2(out[0, :, :, :].contiguous().view(1, L, -1).transpose(1, 2),
                        HSI[0, 0, :, :, :].contiguous().view(1, L, -1).transpose(1, 2))
    loss_sad_1 = loss_sad_1[~torch.isnan(loss_sad_1)]
    loss_sad_1 = torch.sum(loss_sad_1)
    
    loss_sad_2 = loss2(out[1, :, :, :].contiguous().view(1, L, -1).transpose(1, 2),
                        HSI[0, 1, :, :, :].contiguous().view(1, L, -1).transpose(1, 2))
    loss_sad_2 = loss_sad_2[~torch.isnan(loss_sad_2)]
    loss_sad_2 = torch.sum(loss_sad_2)
    
    loss_sad_3 = loss2(out[2, :, :, :].contiguous().view(1, L, -1).transpose(1, 2),
                        HSI[0, 2, :, :, :].contiguous().view(1, L, -1).transpose(1, 2))
    loss_sad_3 = loss_sad_3[~torch.isnan(loss_sad_3)]
    loss_sad_3 = torch.sum(loss_sad_3)
    
    loss_sad_4 = loss2(out[3, :, :, :].contiguous().view(1, L, -1).transpose(1, 2),
                        HSI[0, 3, :, :, :].contiguous().view(1, L, -1).transpose(1, 2))
    loss_sad_4 = loss_sad_4[~torch.isnan(loss_sad_4)]
    loss_sad_4 = torch.sum(loss_sad_4)
    
    loss_sad_5 = loss2(out[4, :, :, :].contiguous().view(1, L, -1).transpose(1, 2),
                        HSI[0, 4, :, :, :].contiguous().view(1, L, -1).transpose(1, 2))
    loss_sad_5 = loss_sad_5[~torch.isnan(loss_sad_5)]
    loss_sad_5 = torch.sum(loss_sad_5)
    
    loss_sad_6 = loss2(out[5, :, :, :].contiguous().view(1, L, -1).transpose(1, 2),
                        HSI[0, 5, :, :, :].contiguous().view(1, L, -1).transpose(1, 2))
    loss_sad_6 = loss_sad_6[~torch.isnan(loss_sad_6)]
    loss_sad_6 = torch.sum(loss_sad_6)
    
    return loss_sad_1, loss_sad_2, loss_sad_3, loss_sad_4, loss_sad_5, loss_sad_6

# %%
import torch
import sys
import os
from utils.dealmat import *
from Muformer_pytorch.muformer_syn1 import Muformer
import matplotlib.pyplot as plt
import torch.nn as nn
import time
from plot import plot_abundance

def main():
    path = './data/synth_dataset_ex1.mat'
    lr = 0.1
    weight_decay = 3e-5
    tv_lamda = 1e-3
    epoch = 1000
    L = 224
    device = 'cuda:0'
    T = 6
    nr1 = 50
    nc1 = 50
    P = 3
    beta = 0.25
    gamma = 0.99
    N = nr1 * nc1
    iter_rec, loss_rec, x_rec = list(), list(), list()
    train_losses = []
    order = (0, 2, 1)
    
    net = Muformer(dim = 600,image_width = 50,image_height = 50,patch_size = 10,channels=L,
    num_frames = T,P = P,depth = 2,heads = 8,dim_head =  60,attn_dropout = 0.1,ff_dropout = 0.1)
    
    # 计算网络参数
    total = sum([param.nelement() for param in net.parameters()])
    print('Number of parameter: % .4fM' % (total / 1e6))
    
    Endmember_1, Endmember_2, Endmember_3, Endmember_4, \
    Endmember_5, Endmember_6, HSI = End_deal(path, device)
    # print(torch.mean(HSI.view(L,nr1*nc1),1).shape)
    model_dict = net.state_dict()
    model_dict['decoder1.0.weight'] = Endmember_1
    model_dict['decoder2.0.weight'] = Endmember_2
    model_dict['decoder3.0.weight'] = Endmember_3
    model_dict['decoder4.0.weight'] = Endmember_4
    model_dict['decoder5.0.weight'] = Endmember_5
    model_dict['decoder6.0.weight'] = Endmember_6
    net.load_state_dict(model_dict)
    
    net.apply(net.weights_init)
    net.to(device)
    loss1 = nn.MSELoss(reduction='mean')
        
    criterionSparse = SparseKLloss()
    optim = torch.optim.Adam(net.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.StepLR(optim, step_size=40, gamma=0.92)
    apply_clamp_inst1 = NonZeroClipper()
    time_start = time.time()

    for iter in range(epoch):
        net.train()
        # print(HSI.shape)
        abu, out, cls_token = net(HSI)

        re_loss1 = loss1(out[0, :, :, :], HSI[0, 0, :, :, :])
        re_loss2 = loss1(out[1, :, :, :], HSI[0, 1, :, :, :])
        re_loss3 = loss1(out[2, :, :, :], HSI[0, 2, :, :, :])
        re_loss4 = loss1(out[3, :, :, :], HSI[0, 3, :, :, :])
        re_loss5 = loss1(out[4, :, :, :], HSI[0, 4, :, :, :])
        re_loss6 = loss1(out[5, :, :, :], HSI[0, 5, :, :, :])
                
        loss_sad_1, loss_sad_2, loss_sad_3, loss_sad_4, loss_sad_5, loss_sad_6 = sad_loss(out=out, HSI=HSI)
        
        loss_sparse = (criterionSparse(abu[0]) + criterionSparse(abu[1]) + criterionSparse(abu[2]) + \
                      criterionSparse(abu[3]) + criterionSparse(abu[4]) + criterionSparse(abu[5]))/T
        
        
        loss_t1 = end_loss(HSI[0, 0, :, :, :], net.decoder1[0].weight)
        loss_t2 = end_loss(HSI[0, 1, :, :, :], net.decoder2[0].weight)
        loss_t3 = end_loss(HSI[0, 2, :, :, :], net.decoder3[0].weight)
        loss_t4 = end_loss(HSI[0, 3, :, :, :], net.decoder4[0].weight)
        loss_t5 = end_loss(HSI[0, 4, :, :, :], net.decoder5[0].weight)
        loss_t6 = end_loss(HSI[0, 5, :, :, :], net.decoder6[0].weight)

        
        total_end_loss = (loss_t1 + loss_t2 + loss_t3 + loss_t4 + loss_t5 + loss_t6)/(T * L)
        
        re_loss = torch.sqrt((re_loss1 + re_loss2 + re_loss3 + re_loss4 + re_loss5 + re_loss6)/ T )
        loss_sad = (loss_sad_1 + loss_sad_2 + loss_sad_3 + loss_sad_4 + loss_sad_5 + loss_sad_6)/(T * nc1 * nr1 * P)
        total_loss = beta * re_loss + gamma * loss_sad + 0.08 * total_end_loss + loss_sparse
        optim.zero_grad()
        total_loss.backward()
        optim.step()
        
        net.decoder1.apply(apply_clamp_inst1)
        net.decoder2.apply(apply_clamp_inst1)
        net.decoder3.apply(apply_clamp_inst1)
        net.decoder4.apply(apply_clamp_inst1)
        net.decoder5.apply(apply_clamp_inst1)
        net.decoder6.apply(apply_clamp_inst1)
        
        scheduler.step()
        if iter % 20 == 0:
            print('Epoch:', iter, '| total loss: %.4f' % total_loss.data, '| reconstruction loss: %.4f' % re_loss.data, 
                  '| SAD loss: %.4f' % loss_sad.data, '| loss_sparse: %.4f' % loss_sparse, '| end_loss: %.4f' % total_end_loss)
        iter_rec.append(iter)
        loss_rec.append(total_loss.cpu().detach().numpy())
            
        
    time_end = time.time()
    total_time = time_end - time_start
    print('The training lasts for {} seconds'.format(time_end - time_start))
    print('-------------------START EVAL---------------------')
    

    net.eval()
    abu_est, re_result, cls_token = net(HSI)

    t1 = net.decoder1[0].weight
    t2 = net.decoder2[0].weight
    t3 = net.decoder3[0].weight
    t4 = net.decoder4[0].weight
    t5 = net.decoder5[0].weight
    t6 = net.decoder6[0].weight

    
    abu = abu_est.contiguous().reshape(T, P, nr1, nc1)
    #abu_est = abu / (torch.sum(abu, dim=1))
    abu = abu.permute(2, 3, 1, 0).cpu().detach().numpy()
    abu = abu[:, :, order, :]
    # change the order of abundance maps
    # abu[:, :, :, 0] = abu[:, :, (2, 1, 0), 0]
    # abu[:, :, :, 1] = abu[:, :, (1, 0, 2), 1]
    # abu[:, :, :, 2] = abu[:, :, (2, 1, 0), 2]
    # abu[:, :, :, 3] = abu[:, :, (0, 2, 1), 3]
    # abu[:, :, :, 4] = abu[:, :, (1, 0, 2), 4]
    # abu[:, :, :, 5] = abu[:, :, (1, 0, 2), 5]
    A_hat = abu
    Y_hat = out.contiguous().view(T, L, -1)
    Y_hat = Y_hat.cpu().detach().numpy()
    Y_hat = Y_hat.transpose(2, 1, 0)
    Mn_hat = torch.zeros((L, P, N, T))
    
    for i in range(N):
        Mn_hat[:, :, i, 0] = t1
    for i in range(N):
        Mn_hat[:, :, i, 1] = t2
    for i in range(N):
        Mn_hat[:, :, i, 2] = t3
    for i in range(N):
        Mn_hat[:, :, i, 3] = t4
    for i in range(N):
        Mn_hat[:, :, i, 4] = t5
    for i in range(N):
        Mn_hat[:, :, i, 5] = t6
        
    Mn_hat = Mn_hat[:, order, :, :]
    # change the order of endmembers
    # Mn_hat[:, :, :, 0] = Mn_hat[:, (2, 1, 0), :, 0]
    # Mn_hat[:, :, :, 1] = Mn_hat[:, (1, 0, 2), :, 1]
    # Mn_hat[:, :, :, 2] = Mn_hat[:, (2, 1, 0), :, 2]
    # Mn_hat[:, :, :, 3] = Mn_hat[:, (0, 2, 1), :, 3]
    # Mn_hat[:, :, :, 4] = Mn_hat[:, (1, 0, 2), :, 4]
    # Mn_hat[:, :, :, 5] = Mn_hat[:, (1, 0, 2), :, 5]

    
    io.savemat('result_' + 'syn' + '.mat', \
                 {'A_hat_VRNN' : A_hat,
                  'Y_hat_VRNN' : Y_hat,
                  'Mn_hat_VRNN': Mn_hat.cpu().detach().numpy(),
                 'time_VRNN': total_time})
    plot_abundance(abu=abu, iter_rec=iter_rec, loss_rec=loss_rec)

    
if __name__=='__main__':
    main()
# Out:
# Number of parameter:  92.2663M
# input SNR = 30[dB]
#
# ... Select the projective proj.
# input SNR = 30[dB]
#
# ... Select the projective proj.
# input SNR = 30[dB]
#
# ... Select the projective proj.
# input SNR = 30[dB]
#
# ... Select the projective proj.
# input SNR = 30[dB]
#
# ... Select the projective proj.
# input SNR = 30[dB]
#
# ... Select the projective proj.
# Epoch: 0 | total loss: 0.1136 | reconstruction loss: 0.1453 | SAD loss: 0.0488 | loss_sparse: 0.0200 | end_loss: 0.1122
# Epoch: 20 | total loss: 0.0841 | reconstruction loss: 0.1086 | SAD loss: 0.0363 | loss_sparse: 0.0200 | end_loss: 0.0124
# Epoch: 40 | total loss: 0.0738 | reconstruction loss: 0.0839 | SAD loss: 0.0272 | loss_sparse: 0.0200 | end_loss: 0.0733
# Epoch: 60 | total loss: 0.0685 | reconstruction loss: 0.0805 | SAD loss: 0.0254 | loss_sparse: 0.0200 | end_loss: 0.0403
# Epoch: 80 | total loss: 0.0649 | reconstruction loss: 0.0745 | SAD loss: 0.0219 | loss_sparse: 0.0200 | end_loss: 0.0579
# Epoch: 100 | total loss: 0.0630 | reconstruction loss: 0.0720 | SAD loss: 0.0217 | loss_sparse: 0.0200 | end_loss: 0.0442
# Epoch: 120 | total loss: 0.0620 | reconstruction loss: 0.0708 | SAD loss: 0.0210 | loss_sparse: 0.0200 | end_loss: 0.0444
# Epoch: 140 | total loss: 0.0618 | reconstruction loss: 0.0702 | SAD loss: 0.0208 | loss_sparse: 0.0200 | end_loss: 0.0451
# Epoch: 160 | total loss: 0.0614 | reconstruction loss: 0.0697 | SAD loss: 0.0207 | loss_sparse: 0.0200 | end_loss: 0.0436
# Epoch: 180 | total loss: 0.0613 | reconstruction loss: 0.0699 | SAD loss: 0.0206 | loss_sparse: 0.0200 | end_loss: 0.0437
# Epoch: 200 | total loss: 0.0609 | reconstruction loss: 0.0688 | SAD loss: 0.0203 | loss_sparse: 0.0200 | end_loss: 0.0446
# Epoch: 220 | total loss: 0.0600 | reconstruction loss: 0.0669 | SAD loss: 0.0200 | loss_sparse: 0.0200 | end_loss: 0.0445
# Epoch: 240 | total loss: 0.0603 | reconstruction loss: 0.0671 | SAD loss: 0.0201 | loss_sparse: 0.0200 | end_loss: 0.0451
# Epoch: 260 | total loss: 0.0603 | reconstruction loss: 0.0677 | SAD loss: 0.0200 | loss_sparse: 0.0200 | end_loss: 0.0446
# Epoch: 280 | total loss: 0.0606 | reconstruction loss: 0.0678 | SAD loss: 0.0202 | loss_sparse: 0.0200 | end_loss: 0.0449
# Epoch: 300 | total loss: 0.0600 | reconstruction loss: 0.0669 | SAD loss: 0.0199 | loss_sparse: 0.0200 | end_loss: 0.0447
# Epoch: 320 | total loss: 0.0608 | reconstruction loss: 0.0681 | SAD loss: 0.0205 | loss_sparse: 0.0200 | end_loss: 0.0432
# Epoch: 340 | total loss: 0.0603 | reconstruction loss: 0.0675 | SAD loss: 0.0200 | loss_sparse: 0.0200 | end_loss: 0.0449
# Epoch: 360 | total loss: 0.0597 | reconstruction loss: 0.0661 | SAD loss: 0.0196 | loss_sparse: 0.0200 | end_loss: 0.0465
# Epoch: 380 | total loss: 0.0603 | reconstruction loss: 0.0672 | SAD loss: 0.0199 | loss_sparse: 0.0200 | end_loss: 0.0467
# Epoch: 400 | total loss: 0.0613 | reconstruction loss: 0.0691 | SAD loss: 0.0207 | loss_sparse: 0.0200 | end_loss: 0.0443
# Epoch: 420 | total loss: 0.0603 | reconstruction loss: 0.0672 | SAD loss: 0.0202 | loss_sparse: 0.0200 | end_loss: 0.0438
# Epoch: 440 | total loss: 0.0604 | reconstruction loss: 0.0678 | SAD loss: 0.0203 | loss_sparse: 0.0200 | end_loss: 0.0411
# Epoch: 460 | total loss: 0.0601 | reconstruction loss: 0.0670 | SAD loss: 0.0200 | loss_sparse: 0.0200 | end_loss: 0.0439
# Epoch: 480 | total loss: 0.0609 | reconstruction loss: 0.0679 | SAD loss: 0.0207 | loss_sparse: 0.0200 | end_loss: 0.0433
# Epoch: 500 | total loss: 0.0599 | reconstruction loss: 0.0663 | SAD loss: 0.0199 | loss_sparse: 0.0200 | end_loss: 0.0444
# Epoch: 520 | total loss: 0.0656 | reconstruction loss: 0.0734 | SAD loss: 0.0240 | loss_sparse: 0.0200 | end_loss: 0.0432
# Epoch: 540 | total loss: 0.0602 | reconstruction loss: 0.0662 | SAD loss: 0.0201 | loss_sparse: 0.0200 | end_loss: 0.0473
# Epoch: 560 | total loss: 0.0595 | reconstruction loss: 0.0657 | SAD loss: 0.0199 | loss_sparse: 0.0200 | end_loss: 0.0431
# Epoch: 580 | total loss: 0.0597 | reconstruction loss: 0.0658 | SAD loss: 0.0200 | loss_sparse: 0.0200 | end_loss: 0.0428
# Epoch: 600 | total loss: 0.0589 | reconstruction loss: 0.0640 | SAD loss: 0.0195 | loss_sparse: 0.0200 | end_loss: 0.0453
# Epoch: 620 | total loss: 0.0586 | reconstruction loss: 0.0639 | SAD loss: 0.0192 | loss_sparse: 0.0200 | end_loss: 0.0447
# Epoch: 640 | total loss: 0.0585 | reconstruction loss: 0.0638 | SAD loss: 0.0192 | loss_sparse: 0.0200 | end_loss: 0.0444
# Epoch: 660 | total loss: 0.0583 | reconstruction loss: 0.0634 | SAD loss: 0.0191 | loss_sparse: 0.0200 | end_loss: 0.0451
# Epoch: 680 | total loss: 0.0569 | reconstruction loss: 0.0612 | SAD loss: 0.0183 | loss_sparse: 0.0200 | end_loss: 0.0441
# Epoch: 700 | total loss: 0.0570 | reconstruction loss: 0.0614 | SAD loss: 0.0183 | loss_sparse: 0.0200 | end_loss: 0.0447
# Epoch: 720 | total loss: 0.0567 | reconstruction loss: 0.0604 | SAD loss: 0.0182 | loss_sparse: 0.0200 | end_loss: 0.0450
# Epoch: 740 | total loss: 0.0571 | reconstruction loss: 0.0609 | SAD loss: 0.0185 | loss_sparse: 0.0200 | end_loss: 0.0449
# Epoch: 760 | total loss: 0.0565 | reconstruction loss: 0.0599 | SAD loss: 0.0180 | loss_sparse: 0.0200 | end_loss: 0.0466
# Epoch: 780 | total loss: 0.0563 | reconstruction loss: 0.0595 | SAD loss: 0.0179 | loss_sparse: 0.0200 | end_loss: 0.0463
# Epoch: 800 | total loss: 0.0565 | reconstruction loss: 0.0602 | SAD loss: 0.0181 | loss_sparse: 0.0200 | end_loss: 0.0446
# Epoch: 820 | total loss: 0.0563 | reconstruction loss: 0.0594 | SAD loss: 0.0179 | loss_sparse: 0.0200 | end_loss: 0.0465
# Epoch: 840 | total loss: 0.0558 | reconstruction loss: 0.0583 | SAD loss: 0.0177 | loss_sparse: 0.0200 | end_loss: 0.0461
# Epoch: 860 | total loss: 0.0557 | reconstruction loss: 0.0579 | SAD loss: 0.0176 | loss_sparse: 0.0200 | end_loss: 0.0475
# Epoch: 880 | total loss: 0.0558 | reconstruction loss: 0.0580 | SAD loss: 0.0176 | loss_sparse: 0.0200 | end_loss: 0.0476
# Epoch: 900 | total loss: 0.0553 | reconstruction loss: 0.0571 | SAD loss: 0.0174 | loss_sparse: 0.0200 | end_loss: 0.0478
# Epoch: 920 | total loss: 0.0551 | reconstruction loss: 0.0568 | SAD loss: 0.0173 | loss_sparse: 0.0200 | end_loss: 0.0472
# Epoch: 940 | total loss: 0.0544 | reconstruction loss: 0.0553 | SAD loss: 0.0168 | loss_sparse: 0.0200 | end_loss: 0.0486
# Epoch: 960 | total loss: 0.0542 | reconstruction loss: 0.0551 | SAD loss: 0.0168 | loss_sparse: 0.0200 | end_loss: 0.0481
# Epoch: 980 | total loss: 0.0542 | reconstruction loss: 0.0547 | SAD loss: 0.0168 | loss_sparse: 0.0200 | end_loss: 0.0484
# The training lasts for 52.70469880104065 seconds
# -------------------START EVAL---------------------

# %%
Epoch: 980 | total loss: 0.0545 | reconstruction loss: 0.0554 | SAD loss: 0.0169 | loss_sparse: 0.0200 | end_loss: 0.0487
# Out:
#   Cell In[3], line 1
#     Epoch: 980 | total loss: 0.0545 | reconstruction loss: 0.0554 | SAD loss: 0.0169 | loss_sparse: 0.0200 | end_loss: 0.0487
#                        ^
# SyntaxError: invalid syntax
